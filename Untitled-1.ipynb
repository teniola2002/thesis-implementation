# %%
from django_plotly_dash import DjangoDash
from dash import html, dcc, Input, Output, State
import dash
import dash_bootstrap_components as dbc
#from ml import predict

# %%
app = DjangoDash("npass_app", external_stylesheets=[dbc.themes.BOOTSTRAP])
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 app = DjangoDash("npass_app", external_stylesheets=[dbc.themes.BOOTSTRAP])
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/django_plotly_dash/dash_wrapper.py:187, in DjangoDash.__init__(self, name, serve_locally, add_bootstrap_links, suppress_callback_exceptions, external_stylesheets, external_scripts, **kwargs)
#     183 add_usable_app(self._uid,
#     184                self)
#     186 if serve_locally is None:
# --> 187     self._serve_locally = serve_locally_setting()
#     188 else:
#     189     self._serve_locally = serve_locally
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/django_plotly_dash/util.py:124, in serve_locally()
#     123 def serve_locally():
# --> 124     return _get_settings().get('serve_locally', False)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/django_plotly_dash/util.py:41, in _get_settings()
#      39 def _get_settings():
#      40     try:
# ---> 41         the_settings = settings.PLOTLY_DASH
#      42     except AttributeError:
#      43         the_settings = None
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/django/conf/__init__.py:75, in LazySettings.__getattr__(self, name)
#      73 """Return the value of a setting and cache it in self.__dict__."""
#      74 if (_wrapped := self._wrapped) is empty:
# ---> 75     self._setup(name)
#      76     _wrapped = self._wrapped
#      77 val = getattr(_wrapped, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/django/conf/__init__.py:55, in LazySettings._setup(self, name)
#      53 if not settings_module:
#      54     desc = ("setting %s" % name) if name else "settings"
# ---> 55     raise ImproperlyConfigured(
#      56         "Requested %s, but settings are not configured. "
#      57         "You must either define the environment variable %s "
#      58         "or call settings.configure() before accessing settings."
#      59         % (desc, ENVIRONMENT_VARIABLE)
#      60     )
#      62 self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting PLOTLY_DASH, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
